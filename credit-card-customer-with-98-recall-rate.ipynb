# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('BankChurners.csv')
data=data[data.columns[1:-2]]
data.head()
# Out:
#       Attrition_Flag  Customer_Age Gender  Dependent_count Education_Level  \
# 0  Existing Customer            45      M                3     High School
# 1  Existing Customer            49      F                5        Graduate
# 2  Existing Customer            51      M                3        Graduate
# 3  Existing Customer            40      F                4     High School
# 4  Existing Customer            40      M                3      Uneducated
#
#   Marital_Status Income_Category Card_Category  Months_on_book  \
# 0        Married     $60K - $80K          Blue              39
# 1         Single  Less than $40K          Blue              44
# 2        Married    $80K - $120K          Blue              36
# 3        Unknown  Less than $40K          Blue              34
# 4        Married     $60K - $80K          Blue              21
#
#    Total_Relationship_Count  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0                         5                       1                      3
# 1                         6                       1                      2
# 2                         4                       1                      0
# 3                         3                       4                      1
# 4                         5                       1                      0
#
#    Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# 0       12691.0                  777          11914.0                 1.335
# 1        8256.0                  864           7392.0                 1.541
# 2        3418.0                    0           3418.0                 2.594
# 3        3313.0                 2517            796.0                 1.405
# 4        4716.0                    0           4716.0                 2.175
#
#    Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 0             1144              42                1.625                  0.061
# 1             1291              33                3.714                  0.105
# 2             1887              20                2.333                  0.000
# 3             1171              20                2.333                  0.760
# 4              816              28                2.500                  0.000

# %%
data.describe()
# Out:
#        Customer_Age  Dependent_count  Months_on_book  \
# count  10127.000000     10127.000000    10127.000000
# mean      46.325960         2.346203       35.928409
# std        8.016814         1.298908        7.986416
# min       26.000000         0.000000       13.000000
# 25%       41.000000         1.000000       31.000000
# 50%       46.000000         2.000000       36.000000
# 75%       52.000000         3.000000       40.000000
# max       73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# 50%                    4.000000                2.000000
# 75%                    5.000000                3.000000
# max                    6.000000                6.000000
#
#        Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# count           10127.000000  10127.000000         10127.000000
# mean                2.455317   8631.953698          1162.814061
# std                 1.106225   9088.776650           814.987335
# min                 0.000000   1438.300000             0.000000
# 25%                 2.000000   2555.000000           359.000000
# 50%                 2.000000   4549.000000          1276.000000
# 75%                 3.000000  11067.500000          1784.000000
# max                 6.000000  34516.000000          2517.000000
#
#        Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# count     10127.000000          10127.000000     10127.000000    10127.000000
# mean       7469.139637              0.759941      4404.086304       64.858695
# std        9090.685324              0.219207      3397.129254       23.472570
# min           3.000000              0.000000       510.000000       10.000000
# 25%        1324.500000              0.631000      2155.500000       45.000000
# 50%        3474.000000              0.736000      3899.000000       67.000000
# 75%        9859.000000              0.859000      4741.000000       81.000000
# max       34516.000000              3.397000     18484.000000      139.000000
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# count         10127.000000           10127.000000
# mean              0.712222               0.274894
# std               0.238086               0.275691
# min               0.000000               0.000000
# 25%               0.582000               0.023000
# 50%               0.702000               0.176000
# 75%               0.818000               0.503000
# max               3.714000               0.999000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Attrition_Flag            10127 non-null  object
#  1   Customer_Age              10127 non-null  int64
#  2   Gender                    10127 non-null  object
#  3   Dependent_count           10127 non-null  int64
#  4   Education_Level           10127 non-null  object
#  5   Marital_Status            10127 non-null  object
#  6   Income_Category           10127 non-null  object
#  7   Card_Category             10127 non-null  object
#  8   Months_on_book            10127 non-null  int64
#  9   Total_Relationship_Count  10127 non-null  int64
#  10  Months_Inactive_12_mon    10127 non-null  int64
#  11  Contacts_Count_12_mon     10127 non-null  int64
#  12  Credit_Limit              10127 non-null  float64
#  13  Total_Revolving_Bal       10127 non-null  int64
#  14  Avg_Open_To_Buy           10127 non-null  float64
#  15  Total_Amt_Chng_Q4_Q1      10127 non-null  float64
#  16  Total_Trans_Amt           10127 non-null  int64
#  17  Total_Trans_Ct            10127 non-null  int64
#  18  Total_Ct_Chng_Q4_Q1       10127 non-null  float64
#  19  Avg_Utilization_Ratio     10127 non-null  float64
# dtypes: float64(5), int64(9), object(6)
# memory usage: 1.5+ MB

# %%
data.isna().sum()
# Out:
# Attrition_Flag              0
# Customer_Age                0
# Gender                      0
# Dependent_count             0
# Education_Level             0
# Marital_Status              0
# Income_Category             0
# Card_Category               0
# Months_on_book              0
# Total_Relationship_Count    0
# Months_Inactive_12_mon      0
# Contacts_Count_12_mon       0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Avg_Open_To_Buy             0
# Total_Amt_Chng_Q4_Q1        0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Total_Ct_Chng_Q4_Q1         0
# Avg_Utilization_Ratio       0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.plot(kind='box',subplots=True,layout=(10,2),figsize=(20,15))
# Out:
# Customer_Age                   AxesSubplot(0.125,0.816017;0.352273x0.0639831)
# Dependent_count             AxesSubplot(0.547727,0.816017;0.352273x0.0639831)
# Months_on_book                 AxesSubplot(0.125,0.739237;0.352273x0.0639831)
# Total_Relationship_Count    AxesSubplot(0.547727,0.739237;0.352273x0.0639831)
# Months_Inactive_12_mon         AxesSubplot(0.125,0.662458;0.352273x0.0639831)
# Contacts_Count_12_mon       AxesSubplot(0.547727,0.662458;0.352273x0.0639831)
# Credit_Limit                   AxesSubplot(0.125,0.585678;0.352273x0.0639831)
# Total_Revolving_Bal         AxesSubplot(0.547727,0.585678;0.352273x0.0639831)
# Avg_Open_To_Buy                AxesSubplot(0.125,0.508898;0.352273x0.0639831)
# Total_Amt_Chng_Q4_Q1        AxesSubplot(0.547727,0.508898;0.352273x0.0639831)
# Total_Trans_Amt                AxesSubplot(0.125,0.432119;0.352273x0.0639831)
# Total_Trans_Ct              AxesSubplot(0.547727,0.432119;0.352273x0.0639831)
# Total_Ct_Chng_Q4_Q1            AxesSubplot(0.125,0.355339;0.352273x0.0639831)
# Avg_Utilization_Ratio       AxesSubplot(0.547727,0.355339;0.352273x0.0639831)
# dtype: object

# %%
data.plot(kind='density',subplots=True,layout=(10,2),figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D2411DD2B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D2418BBB70>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D241BA3B70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D241BD7B70>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D241C0CB70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D241C43B70>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D241C76B70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D241CACB38>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D241CACBA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D241D18B70>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D241D4CB70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D241D82B70>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D241DB7B70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D241DEEB70>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D241E23B70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D241E56DD8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D241E9A080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D241ECC2E8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D241F01550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D241F347B8>]],
#       dtype=object)

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Attrition Flag

# %%
data['Attrition_Flag'].nunique()
# Out:
# 2

# %%
data['Attrition_Flag'].unique()
# Out:
# array(['Existing Customer', 'Attrited Customer'], dtype=object)

# %%
data['Attrition_Flag'].value_counts()
# Out:
# Existing Customer    8500
# Attrited Customer    1627
# Name: Attrition_Flag, dtype: int64

# %%
sns.countplot(data=data,x='Attrition_Flag')

# %% [markdown]
# ### Customer Age

# %%
data['Customer_Age'].nunique()
# Out:
# 45

# %%
sns.distplot(data['Customer_Age'])

# %%
sns.boxplot(data=data,y='Customer_Age')

# %%
sns.boxplot(data=data,x='Attrition_Flag',y='Customer_Age')

# %% [markdown]
# ### Gender

# %%
data['Gender'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
data['Gender'].value_counts()
# Out:
# F    5358
# M    4769
# Name: Gender, dtype: int64

# %%
sns.countplot(data=data,x='Gender',hue='Attrition_Flag')

# %% [markdown]
# ### Dependent Count

# %%
data['Dependent_count'].nunique()
# Out:
# 6

# %%
data['Dependent_count'].unique()
# Out:
# array([3, 5, 4, 2, 0, 1], dtype=int64)

# %%
sns.countplot(data=data,x='Dependent_count')

# %%
sns.countplot(data=data,x='Dependent_count',hue='Attrition_Flag')

# %% [markdown]
# ### Education Level

# %%
data['Education_Level'].nunique()
# Out:
# 7

# %%
data['Education_Level'].unique()
# Out:
# array(['High School', 'Graduate', 'Uneducated', 'Unknown', 'College',
#        'Post-Graduate', 'Doctorate'], dtype=object)

# %%
data['Education_Level'].value_counts()
# Out:
# Graduate         3128
# High School      2013
# Unknown          1519
# Uneducated       1487
# College          1013
# Post-Graduate     516
# Doctorate         451
# Name: Education_Level, dtype: int64

# %%
plt.figure(figsize=(15,7))
sns.countplot(data=data,x='Education_Level')

# %%
plt.figure(figsize=(15,7))
sns.countplot(data=data,x='Education_Level',hue='Attrition_Flag')

# %% [markdown]
# ### Marital Status

# %%
data['Marital_Status'].nunique()
# Out:
# 4

# %%
data['Marital_Status'].unique()
# Out:
# array(['Married', 'Single', 'Unknown', 'Divorced'], dtype=object)

# %%
data['Marital_Status'].value_counts()
# Out:
# Married     4687
# Single      3943
# Unknown      749
# Divorced     748
# Name: Marital_Status, dtype: int64

# %%
sns.countplot(data=data,x='Marital_Status')

# %%
sns.countplot(data=data,x='Marital_Status',hue='Attrition_Flag')

# %% [markdown]
# ### Income Category

# %%
data['Income_Category'].nunique()
# Out:
# 6

# %%
data['Income_Category'].unique()
# Out:
# array(['$60K - $80K', 'Less than $40K', '$80K - $120K', '$40K - $60K',
#        '$120K +', 'Unknown'], dtype=object)

# %%
data['Income_Category'].value_counts()
# Out:
# Less than $40K    3561
# $40K - $60K       1790
# $80K - $120K      1535
# $60K - $80K       1402
# Unknown           1112
# $120K +            727
# Name: Income_Category, dtype: int64

# %%
plt.figure(figsize=(12,7))
sns.countplot(data=data,x='Income_Category')

# %%
plt.figure(figsize=(12,7))
sns.countplot(data=data,x='Income_Category',hue='Attrition_Flag')

# %% [markdown]
# ### Card Category

# %%
data['Card_Category'].nunique()
# Out:
# 4

# %%
data['Card_Category'].unique()
# Out:
# array(['Blue', 'Gold', 'Silver', 'Platinum'], dtype=object)

# %%
data['Card_Category'].value_counts()
# Out:
# Blue        9436
# Silver       555
# Gold         116
# Platinum      20
# Name: Card_Category, dtype: int64

# %%
sns.countplot(data=data,x='Card_Category')

# %%
sns.countplot(data=data,x='Card_Category',hue='Attrition_Flag')

# %% [markdown]
# ### Months of book

# %%
data['Months_on_book'].nunique()
# Out:
# 44

# %%
data['Months_on_book'].unique()
# Out:
# array([39, 44, 36, 34, 21, 46, 27, 31, 54, 30, 48, 37, 56, 42, 49, 33, 28,
#        38, 41, 43, 45, 52, 40, 50, 35, 47, 32, 20, 29, 25, 53, 24, 55, 23,
#        22, 26, 13, 51, 19, 15, 17, 18, 16, 14], dtype=int64)

# %%
data['Months_on_book'].value_counts()
# Out:
# 36    2463
# 37     358
# 34     353
# 38     347
# 39     341
# 40     333
# 31     318
# 35     317
# 33     305
# 30     300
# 41     297
# 32     289
# 28     275
# 43     273
# 42     271
# 29     241
# 44     230
# 45     227
# 27     206
# 46     197
# 26     186
# 47     171
# 25     165
# 48     162
# 24     160
# 49     141
# 23     116
# 22     105
# 56     103
# 50      96
# 21      83
# 51      80
# 53      78
# 20      74
# 13      70
# 19      63
# 52      62
# 18      58
# 54      53
# 55      42
# 17      39
# 15      34
# 16      29
# 14      16
# Name: Months_on_book, dtype: int64

# %%
sns.distplot(data['Months_on_book'])

# %%
sns.boxplot(data=data,y='Months_on_book')

# %%
sns.boxplot(data=data,x='Attrition_Flag',y='Months_on_book')

# %% [markdown]
# ### Total Relationship Count

# %%
data['Total_Relationship_Count'].nunique()
# Out:
# 6

# %%
data['Total_Relationship_Count'].unique()
# Out:
# array([5, 6, 4, 3, 2, 1], dtype=int64)

# %%
data['Total_Relationship_Count'].value_counts()
# Out:
# 3    2305
# 4    1912
# 5    1891
# 6    1866
# 2    1243
# 1     910
# Name: Total_Relationship_Count, dtype: int64

# %%
sns.countplot(data=data,x='Total_Relationship_Count')

# %%
sns.countplot(data=data,x='Total_Relationship_Count',hue='Attrition_Flag')

# %% [markdown]
# ### Months Inactive 12 mon

# %%
data['Months_Inactive_12_mon'].unique()
# Out:
# array([1, 4, 2, 3, 6, 0, 5], dtype=int64)

# %%
data['Months_Inactive_12_mon'].nunique()
# Out:
# 7

# %%
data['Months_Inactive_12_mon'].value_counts()
# Out:
# 3    3846
# 2    3282
# 1    2233
# 4     435
# 5     178
# 6     124
# 0      29
# Name: Months_Inactive_12_mon, dtype: int64

# %%
sns.countplot(data=data,x='Months_Inactive_12_mon')

# %%
sns.countplot(data=data,x='Months_Inactive_12_mon',hue='Attrition_Flag')

# %% [markdown]
# ### Contacts Count 12 mon

# %%
data['Contacts_Count_12_mon'].nunique()
# Out:
# 7

# %%
data['Contacts_Count_12_mon'].unique()
# Out:
# array([3, 2, 0, 1, 4, 5, 6], dtype=int64)

# %%
sns.countplot(data=data,x='Contacts_Count_12_mon')

# %%
sns.countplot(data=data,x='Contacts_Count_12_mon',hue='Attrition_Flag')

# %% [markdown]
# ### Credit Limit

# %%
data['Credit_Limit'].nunique()
# Out:
# 6205

# %%
data['Credit_Limit'].unique()
# Out:
# array([12691.,  8256.,  3418., ...,  5409.,  5281., 10388.])

# %%
sns.distplot(data['Credit_Limit'])

# %%
sns.boxplot(data=data,y='Credit_Limit')

# %%
sns.boxplot(data=data,y='Credit_Limit',x='Attrition_Flag')

# %% [markdown]
# ### Total Revolving Bal

# %%
data['Total_Revolving_Bal'].nunique()
# Out:
# 1974

# %%
sns.distplot(data['Total_Revolving_Bal'])

# %%
sns.boxplot(data=data,y='Total_Revolving_Bal')

# %%
sns.boxplot(data=data,x='Attrition_Flag',y='Total_Revolving_Bal')

# %% [markdown]
# ### Avg Open To Buy

# %%
data['Avg_Open_To_Buy'].nunique()
# Out:
# 6813

# %%
sns.distplot(data['Avg_Open_To_Buy'])

# %%
sns.boxplot(data=data,y='Avg_Open_To_Buy')

# %%
sns.boxplot(data=data,x='Attrition_Flag',y='Avg_Open_To_Buy')

# %% [markdown]
# ### Total Amt Chng Q4 Q1

# %%
data['Total_Amt_Chng_Q4_Q1'].nunique()
# Out:
# 1158

# %%
sns.distplot(data['Total_Amt_Chng_Q4_Q1'])

# %%
sns.boxplot(data=data,y='Total_Amt_Chng_Q4_Q1')

# %%
sns.boxplot(data=data,y='Total_Amt_Chng_Q4_Q1',x='Attrition_Flag')

# %% [markdown]
# ### Total Trans Amt

# %%
data['Total_Trans_Amt'].nunique()
# Out:
# 5033

# %%
sns.distplot(data['Total_Trans_Amt'])

# %%
sns.boxplot(data=data,y='Total_Trans_Amt')

# %%
sns.boxplot(data=data,x='Attrition_Flag',y='Total_Trans_Amt')

# %% [markdown]
# ### Total Trans Ct

# %%
data['Total_Trans_Ct'].nunique()
# Out:
# 126

# %%
data['Total_Trans_Ct'].value_counts()
# Out:
# 81     208
# 75     203
# 71     203
# 82     202
# 69     202
#       ...
# 11       2
# 138      1
# 139      1
# 132      1
# 134      1
# Name: Total_Trans_Ct, Length: 126, dtype: int64

# %%
sns.distplot(data['Total_Trans_Ct'])

# %%
sns.boxplot(data=data,y='Total_Trans_Ct')

# %%
sns.boxplot(data=data,x='Attrition_Flag',y='Total_Trans_Ct')

# %% [markdown]
# ### Total Ct Chng Q4 Q1

# %%
data['Total_Ct_Chng_Q4_Q1'].nunique()
# Out:
# 830

# %%
sns.distplot(data['Total_Ct_Chng_Q4_Q1'])

# %%
sns.boxplot(data=data,y='Total_Ct_Chng_Q4_Q1')

# %%
sns.boxplot(data=data,x='Attrition_Flag',y='Total_Ct_Chng_Q4_Q1')

# %% [markdown]
# ### Avg Utilization Ratio

# %%
data['Avg_Utilization_Ratio'].nunique()
# Out:
# 964

# %%
sns.distplot(data['Avg_Utilization_Ratio'])

# %%
sns.boxplot(data=data,y='Avg_Utilization_Ratio')

# %%
sns.boxplot(data=data,x='Attrition_Flag',y='Avg_Utilization_Ratio')

# %% [markdown]
# ## Data Cleaning

# %%
data.isna().sum()
# Out:
# Attrition_Flag              0
# Customer_Age                0
# Gender                      0
# Dependent_count             0
# Education_Level             0
# Marital_Status              0
# Income_Category             0
# Card_Category               0
# Months_on_book              0
# Total_Relationship_Count    0
# Months_Inactive_12_mon      0
# Contacts_Count_12_mon       0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Avg_Open_To_Buy             0
# Total_Amt_Chng_Q4_Q1        0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Total_Ct_Chng_Q4_Q1         0
# Avg_Utilization_Ratio       0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
def outliers(col):
    global data
    curr=len(data)
    prev=0
    while curr!=prev:
        q1=data[col].describe()[4]
        q3=data[col].describe()[6]
        iqr=q3-q1
        up=q3+1.5*iqr
        low=q1-1.5*iqr
        if q3==q1 or low==up:
            pass
        else:
            data=data[(data[col]>low)&(data[col]<up)]
            prev=curr
            curr=len(data)

# %% [markdown]
# ### Customer Age

# %%
sns.boxplot(data=data,y='Customer_Age')

# %%
outliers('Customer_Age')
sns.boxplot(data=data,y='Customer_Age')

# %% [markdown]
# ### Education Level

# %%
data['Education_Level'].unique()
# Out:
# array(['High School', 'Graduate', 'Uneducated', 'Unknown', 'College',
#        'Post-Graduate', 'Doctorate'], dtype=object)

# %%
plt.figure(figsize=(14,7))
sns.countplot(data=data,x='Education_Level')

# %%
data['Education_Level'].value_counts()
# Out:
# Graduate         3128
# High School      2011
# Unknown          1519
# Uneducated       1487
# College          1013
# Post-Graduate     516
# Doctorate         451
# Name: Education_Level, dtype: int64

# %%
bools=data[data['Education_Level']=='Unknown']['Education_Level'].value_counts()[0]<int(len(data)/10)
if bools==False:
    data=data[data['Education_Level']!='Unknown']
len(data)
# Out:
# 8606

# %%
plt.figure(figsize=(14,7))
sns.countplot(data=data,x='Education_Level')

# %% [markdown]
# ### Marital Status

# %%
data['Marital_Status'].value_counts()
# Out:
# Married     3997
# Single      3322
# Divorced     652
# Unknown      635
# Name: Marital_Status, dtype: int64

# %%
data[data['Marital_Status']=='Unknown'].describe()
# Out:
#        Customer_Age  Dependent_count  Months_on_book  \
# count    635.000000       635.000000      635.000000
# mean      45.565354         2.527559       35.229921
# std        6.882983         1.266075        7.241925
# min       26.000000         0.000000       13.000000
# 25%       42.000000         2.000000       32.000000
# 50%       45.000000         3.000000       36.000000
# 75%       49.000000         3.000000       39.000000
# max       65.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count                635.000000              635.000000
# mean                   3.740157                2.352756
# std                    1.608400                1.049998
# min                    1.000000                1.000000
# 25%                    2.000000                2.000000
# 50%                    4.000000                2.000000
# 75%                    5.000000                3.000000
# max                    6.000000                6.000000
#
#        Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# count             635.000000    635.000000           635.000000
# mean                2.425197   9504.046457          1139.940157
# std                 1.089958   9607.557813           836.775318
# min                 0.000000   1438.300000             0.000000
# 25%                 2.000000   2695.000000             0.000000
# 50%                 2.000000   5222.000000          1252.000000
# 75%                 3.000000  13260.500000          1784.500000
# max                 6.000000  34516.000000          2517.000000
#
#        Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# count       635.000000            635.000000       635.000000      635.000000
# mean       8364.106299              0.745277      4704.888189       67.149606
# std        9653.261981              0.189068      3296.966682       22.744250
# min         111.000000              0.018000       647.000000       15.000000
# 25%        1438.300000              0.636000      2439.500000       48.500000
# 50%        3930.000000              0.731000      4190.000000       69.000000
# 75%       12061.500000              0.854000      4889.000000       82.000000
# max       34516.000000              2.204000     16098.000000      131.000000
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# count           635.000000             635.000000
# mean              0.712362               0.252191
# std               0.220611               0.267305
# min               0.077000               0.000000
# 25%               0.581500               0.000000
# 50%               0.700000               0.145000
# 75%               0.813000               0.460500
# max               2.333000               0.958000

# %%
data[data['Marital_Status']=='Divorced'].describe()
# Out:
#        Customer_Age  Dependent_count  Months_on_book  \
# count    652.000000       652.000000      652.000000
# mean      45.009202         2.369632       35.246933
# std        7.588894         1.287968        7.355912
# min       26.000000         0.000000       13.000000
# 25%       41.000000         2.000000       31.000000
# 50%       45.000000         2.000000       36.000000
# 75%       49.000000         3.000000       39.000000
# max       65.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count                652.000000              652.000000
# mean                   3.855828                2.371166
# std                    1.537273                1.023666
# min                    1.000000                1.000000
# 25%                    3.000000                2.000000
# 50%                    4.000000                2.000000
# 75%                    5.000000                3.000000
# max                    6.000000                6.000000
#
#        Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# count             652.000000    652.000000           652.000000
# mean                2.424847   9371.885890          1165.595092
# std                 1.112226   9534.039924           818.749428
# min                 0.000000   1438.300000             0.000000
# 25%                 2.000000   2694.250000           243.750000
# 50%                 2.000000   5263.500000          1297.500000
# 75%                 3.000000  12047.500000          1789.000000
# max                 6.000000  34516.000000          2517.000000
#
#        Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# count       652.000000            652.000000       652.000000      652.000000
# mean       8206.290798              0.755293      4597.319018       67.599693
# std        9535.338195              0.188465      3434.889299       22.306568
# min          10.000000              0.000000       781.000000       20.000000
# 25%        1438.300000              0.650000      2465.000000       51.000000
# 50%        4141.000000              0.742000      3911.000000       69.000000
# 75%       11013.750000              0.857000      4755.000000       82.000000
# max       34516.000000              2.368000     17038.000000      127.000000
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# count           652.000000             652.000000
# mean              0.708584               0.259301
# std               0.211028               0.265409
# min               0.000000               0.000000
# 25%               0.591000               0.015500
# 50%               0.703000               0.163500
# 75%               0.816000               0.464500
# max               2.000000               0.995000

# %%
sample=data[(data['Marital_Status']=='Unknown')|(data['Marital_Status']=='Divorced')]

# %%
sns.countplot(data=sample,x='Marital_Status')

# %% [markdown]
# ### Income Category

# %%
plt.figure(figsize=(12,7))
sns.countplot(data=data,x='Income_Category')

# %%
data['Income_Category'].value_counts()
# Out:
# Less than $40K    3004
# $40K - $60K       1520
# $80K - $120K      1316
# $60K - $80K       1192
# Unknown            967
# $120K +            607
# Name: Income_Category, dtype: int64

# %%
data[data['Income_Category']!='Unknown'].describe()
# Out:
#        Customer_Age  Dependent_count  Months_on_book  \
# count   7639.000000      7639.000000     7639.000000
# mean      46.297159         2.352140       35.947899
# std        7.949380         1.290018        7.939491
# min       26.000000         0.000000       13.000000
# 25%       41.000000         1.000000       31.000000
# 50%       46.000000         2.000000       36.000000
# 75%       52.000000         3.000000       40.000000
# max       68.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count               7639.000000             7639.000000
# mean                   3.814505                2.343370
# std                    1.550585                1.000022
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# 50%                    4.000000                2.000000
# 75%                    5.000000                3.000000
# max                    6.000000                6.000000
#
#        Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# count            7639.000000   7639.000000          7639.000000
# mean                2.450975   8560.413392          1166.084959
# std                 1.103174   9163.089705           813.379947
# min                 0.000000   1438.300000             0.000000
# 25%                 2.000000   2507.000000           450.500000
# 50%                 2.000000   4343.000000          1280.000000
# 75%                 3.000000  10878.500000          1781.000000
# max                 6.000000  34516.000000          2517.000000
#
#        Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# count      7639.000000           7639.000000      7639.000000     7639.000000
# mean       7394.328433              0.759294      4416.165205       64.677707
# std        9172.720324              0.221042      3457.275099       23.739174
# min           3.000000              0.000000       510.000000       10.000000
# 25%        1254.500000              0.630000      2110.000000       44.500000
# 50%        3292.000000              0.735000      3866.000000       67.000000
# 75%        9668.000000              0.857500      4751.000000       81.000000
# max       34516.000000              3.397000     17995.000000      134.000000
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# count          7639.000000            7639.000000
# mean              0.711367               0.280636
# std               0.237752               0.278185
# min               0.000000               0.000000
# 25%               0.583000               0.024500
# 50%               0.700000               0.184000
# 75%               0.818000               0.513000
# max               3.714000               0.999000

# %%
data=data[data['Income_Category']!='Unknown']
data.describe()
# Out:
#        Customer_Age  Dependent_count  Months_on_book  \
# count   7639.000000      7639.000000     7639.000000
# mean      46.297159         2.352140       35.947899
# std        7.949380         1.290018        7.939491
# min       26.000000         0.000000       13.000000
# 25%       41.000000         1.000000       31.000000
# 50%       46.000000         2.000000       36.000000
# 75%       52.000000         3.000000       40.000000
# max       68.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count               7639.000000             7639.000000
# mean                   3.814505                2.343370
# std                    1.550585                1.000022
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# 50%                    4.000000                2.000000
# 75%                    5.000000                3.000000
# max                    6.000000                6.000000
#
#        Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# count            7639.000000   7639.000000          7639.000000
# mean                2.450975   8560.413392          1166.084959
# std                 1.103174   9163.089705           813.379947
# min                 0.000000   1438.300000             0.000000
# 25%                 2.000000   2507.000000           450.500000
# 50%                 2.000000   4343.000000          1280.000000
# 75%                 3.000000  10878.500000          1781.000000
# max                 6.000000  34516.000000          2517.000000
#
#        Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# count      7639.000000           7639.000000      7639.000000     7639.000000
# mean       7394.328433              0.759294      4416.165205       64.677707
# std        9172.720324              0.221042      3457.275099       23.739174
# min           3.000000              0.000000       510.000000       10.000000
# 25%        1254.500000              0.630000      2110.000000       44.500000
# 50%        3292.000000              0.735000      3866.000000       67.000000
# 75%        9668.000000              0.857500      4751.000000       81.000000
# max       34516.000000              3.397000     17995.000000      134.000000
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# count          7639.000000            7639.000000
# mean              0.711367               0.280636
# std               0.237752               0.278185
# min               0.000000               0.000000
# 25%               0.583000               0.024500
# 50%               0.700000               0.184000
# 75%               0.818000               0.513000
# max               3.714000               0.999000

# %% [markdown]
# ## Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder,MinMaxScaler

# %%
minmax = MinMaxScaler()
le = LabelEncoder()

# %%
col=data.select_dtypes(include='object').columns
col
# Out:
# Index(['Attrition_Flag', 'Gender', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category'],
#       dtype='object')

# %%
data[col]=data[col].apply(le.fit_transform)

# %%
cols=data.select_dtypes(include=['int64','float64']).columns[1:-1]
cols
# Out:
# Index(['Dependent_count', 'Months_on_book', 'Total_Relationship_Count',
#        'Months_Inactive_12_mon', 'Contacts_Count_12_mon', 'Credit_Limit',
#        'Total_Revolving_Bal', 'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1',
#        'Total_Trans_Amt', 'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1'],
#       dtype='object')

# %%
data[cols]=minmax.fit_transform(data[cols])

# %% [markdown]
# ### Feature Engineering

# %%
plt.figure(figsize=(15,7))
sns.heatmap(data.corr(),annot=True,fmt='.2f')

# %%
from sklearn.feature_selection import SelectKBest,chi2,f_classif,mutual_info_classif,SelectPercentile

# %%
skc = SelectKBest(score_func=f_classif).fit(data.drop(['Attrition_Flag'],axis=1),data['Attrition_Flag'])
features = pd.DataFrame(skc.scores_,data.drop(['Attrition_Flag'],axis=1).columns)
features.sort_values(by=0,ascending=False)
# Out:
#                                     0
# Total_Trans_Ct            1151.802542
# Total_Ct_Chng_Q4_Q1        662.115305
# Total_Revolving_Bal        575.002717
# Contacts_Count_12_mon      294.314369
# Avg_Utilization_Ratio      261.374351
# Total_Trans_Amt            211.479257
# Months_Inactive_12_mon     183.342844
# Total_Relationship_Count   160.885152
# Total_Amt_Chng_Q4_Q1       143.156872
# Gender                       9.526075
# Income_Category              3.169649
# Marital_Status               3.079593
# Credit_Limit                 1.960850
# Dependent_count              1.448369
# Months_on_book               1.301151
# Customer_Age                 0.933200
# Avg_Open_To_Buy              0.424972
# Education_Level              0.009889
# Card_Category                0.007937

# %%
cols=features[features[0]>100].index
cols
# Out:
# Index(['Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Total_Revolving_Bal', 'Total_Amt_Chng_Q4_Q1',
#        'Total_Trans_Amt', 'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1',
#        'Avg_Utilization_Ratio'],
#       dtype='object')

# %% [markdown]
# ## Data Modeling

# %%
from sklearn.metrics import accuracy_score,f1_score,classification_report,confusion_matrix,recall_score
from sklearn.model_selection import train_test_split

# %%
train_x,test_x,train_y,test_y=train_test_split(data[cols],data['Attrition_Flag'],test_size=0.3,random_state=11)

# %%
from xgboost import XGBClassifier

# %%
xgc=XGBClassifier()
xgc.fit(train_x,train_y)
predict=xgc.predict(test_x)
print('Accuracy Score',accuracy_score(predict,test_y)*100)
print('F1 Score',f1_score(predict,test_y)*100)
print('Recall Score',recall_score(predict,test_y)*100)
print('Classification Report\n',classification_report(predict,test_y))
print('Confusion Matrix\n',confusion_matrix(predict,test_y))
# Out:
# Accuracy Score 96.50959860383944
# F1 Score 97.93067770305225
# Recall Score 97.77892561983471
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89       356
#            1       0.98      0.98      0.98      1936
#
#     accuracy                           0.97      2292
#    macro avg       0.93      0.94      0.93      2292
# weighted avg       0.97      0.97      0.97      2292
#
# Confusion Matrix
#  [[ 319   37]
#  [  43 1893]]
